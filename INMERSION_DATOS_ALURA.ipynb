# %% [markdown]
# <a href="https://colab.research.google.com/github/max6811/inmersion_datos_alura/blob/main/INMERSION_DATOS_ALURA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Welcome our first meeting in data immersion**

# %%
from google.colab import drive

#montamos nuestro contenido de drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

inmuebles = pd.read_csv('/content/drive/MyDrive/COURSES/imercion_de_datos_alura/inmuebles_bogota.csv')

inmuebles.head()
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Baños  Área              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor
# 0    $ 360.000.000
# 1    $ 670.000.000
# 2  $ 1.120.000.000
# 3    $ 890.000.000
# 4    $ 970.000.000

# %% [markdown]
# Verify our data shape

# %%
inmuebles.shape
# Out:
# (9520, 8)

# %%
inmuebles.columns
# Out:
# Index(['Tipo', 'Descripcion', 'Habitaciones', 'Baños', 'Área', 'Barrio', 'UPZ',
#        'Valor'],
#       dtype='object')

# %% [markdown]
# Dictionary in python for rename colums

# %%
columnas = {'Baños': 'Banos', 'Área': 'Area'}
inmuebles = inmuebles.rename(columns=columnas)

inmuebles.sample(10)
# Out:
#                      Tipo                                  Descripcion  \
# 4601                 Casa              Casa en venta en Barrios Unidos
# 6958          Apartamento   Apartamento en venta en Zona Noroccidental
# 8357          Apartamento             Apartamento en venta en El Batán
# 5461          Apartamento             Apartamento en venta en Cedritos
# 275                  Casa          Casa en venta en Zona Noroccidental
# 2636  Oficina/Consultorio  Oficina/Consultorio en venta en Los Rosales
# 8266          Apartamento          Apartamento en venta en Teusaquillo
# 1791                 Casa          Casa en venta en Zona Noroccidental
# 691           Apartamento              Apartamento en venta en El Plan
# 5991          Apartamento      Apartamento en venta en Chico Reservado
#
#       Habitaciones  Banos  Area              Barrio  \
# 4601             2      2   111      Barrios Unidos
# 6958             2      1    48  Zona Noroccidental
# 8357             3      2    70            El Batán
# 5461             3      2   104            Cedritos
# 275              3      2    89  Zona Noroccidental
# 2636             1      1   250         Los Rosales
# 8266             3      3   145         Teusaquillo
# 1791             5      5   266  Zona Noroccidental
# 691              3      2   106             El Plan
# 5991             1      2    60     Chico Reservado
#
#                                      UPZ            Valor
# 4601                           Los Andes    $ 720.000.000
# 6958  CHAPINERO: Pardo Rubio + Chapinero    $ 175.000.000
# 8357                         La Alhambra    $ 361.000.000
# 5461                             Usaquén    $ 367.500.000
# 275   CHAPINERO: Pardo Rubio + Chapinero    $ 300.000.000
# 2636  CHAPINERO: Chicó Lago + El Refugio  $ 2.755.500.000
# 8266                         Teusaquillo    $ 900.000.000
# 1791  CHAPINERO: Pardo Rubio + Chapinero  $ 1.300.000.000
# 691                            El Rincón    $ 491.000.000
# 5991  CHAPINERO: Chicó Lago + El Refugio    $ 499.500.000

# %% [markdown]
# Obtener informacion de nuestro data frame para poder tener una mejor interpretacion de la informacion de datos.

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 595.1+ KB

# %% [markdown]
# filtrar o localizar por indice

# %%
inmuebles.iloc[300]
# Out:
# Tipo                                Apartamento
# Descripcion     Apartamento en venta en Kennedy
# Habitaciones                                  2
# Banos                                         1
# Area                                         42
# Barrio                                  Kennedy
# UPZ                             Kennedy Central
# Valor                             $ 116.100.000
# Name: 300, dtype: object

# %%
inmuebles.iloc[300: 305]
# Out:
#             Tipo                          Descripcion  Habitaciones  Banos  \
# 300  Apartamento      Apartamento en venta en Kennedy             2      1
# 301  Apartamento  Apartamento en venta en Chico Norte             2      2
# 302  Apartamento      Apartamento en venta en Kennedy             3      2
# 303  Apartamento      Apartamento en venta en Kennedy             3      2
# 304  Apartamento     Apartamento en venta en Cedritos             4      4
#
#      Area       Barrio                                 UPZ          Valor
# 300    42      Kennedy                     Kennedy Central  $ 116.100.000
# 301    95  Chico Norte  CHAPINERO: Chicó Lago + El Refugio  $ 980.000.000
# 302    54      Kennedy                     Kennedy Central  $ 237.000.000
# 303    67      Kennedy                     Kennedy Central  $ 320.000.000
# 304   132     Cedritos                             Usaquén  $ 530.000.000

# %%
inmuebles['Valor'][300]
# Out:
# '$ 116.100.000'

# %%
inmuebles['Valor'][300:305]
# Out:
# 300    $ 116.100.000
# 301    $ 980.000.000
# 302    $ 237.000.000
# 303    $ 320.000.000
# 304    $ 530.000.000
# Name: Valor, dtype: object

# %% [markdown]
# Saber el tipo de dato de nuestra salida

# %%
type(inmuebles['Valor'][300:305])
# Out:
# pandas.core.series.Series

# %% [markdown]
# - Calcular el promedio de la columna Area

# %%
inmuebles.Area.mean()
# Out:
# 146.66470588235293

# %%
from numpy.lib.function_base import average
average(inmuebles['Area'])
# Out:
# 146.66470588235293

# %% [markdown]
# inmuebles que cumplen la condicion, dentro de un barrio llamado chico reservado

# %%
(inmuebles.Barrio == 'Chico Reservado')
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 9515    False
# 9516    False
# 9517    False
# 9518    False
# 9519    False
# Name: Barrio, Length: 9520, dtype: bool

# %%
sum((inmuebles.Barrio == 'Chico Reservado'))
# Out:
# 225

# %%
inmuebles_chico = (inmuebles.Barrio == 'Chico Reservado')
type(inmuebles_chico)
# Out:
# pandas.core.series.Series

# %%
#listamos nuestro frame que obtuvimos de la condicon 
chico_reservado = inmuebles[inmuebles_chico]
chico_reservado
# Out:
#              Tipo                              Descripcion  Habitaciones  \
# 2     Apartamento  Apartamento en venta en Chico Reservado             3
# 39    Apartamento  Apartamento en venta en Chico Reservado             1
# 72    Apartamento  Apartamento en venta en Chico Reservado             1
# 126   Apartamento  Apartamento en venta en Chico Reservado             3
# 143   Apartamento  Apartamento en venta en Chico Reservado             2
# ...           ...                                      ...           ...
# 9299  Apartamento  Apartamento en venta en Chico Reservado             3
# 9335  Apartamento  Apartamento en venta en Chico Reservado             3
# 9341  Apartamento  Apartamento en venta en Chico Reservado             2
# 9472  Apartamento  Apartamento en venta en Chico Reservado             3
# 9506  Apartamento  Apartamento en venta en Chico Reservado             3
#
#       Banos  Area           Barrio                                 UPZ  \
# 2         3   144  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 39        1    64  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 72        1    64  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 126       4   150  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 143       4   104  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# ...     ...   ...              ...                                 ...
# 9299      3   148  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 9335      3   176  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 9341      3   118  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 9472      1    49  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 9506      4   390  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
#
#                 Valor
# 2     $ 1.120.000.000
# 39      $ 495.000.000
# 72      $ 495.000.000
# 126   $ 1.300.000.000
# 143   $ 1.100.000.000
# ...               ...
# 9299    $ 780.000.000
# 9335    $ 850.000.000
# 9341    $ 700.000.000
# 9472    $ 200.000.000
# 9506  $ 3.200.000.000
#
# [225 rows x 8 columns]

# %%
chico_reservado.Area.mean()
# Out:
# 142.78666666666666

# %%
#cuantos barrios tenemos en nuestro data set
len(inmuebles.Barrio.value_counts())
# Out:
# 149

# %%
inmuebles.Barrio.value_counts()
# Out:
# Usaquén               1105
# Zona Noroccidental     877
# Bosa                   589
# Kennedy                589
# Cedritos               554
#                       ...
# Colinas De Suba          1
# La Estanzuela            1
# Roma                     1
# Alameda                  1
# Prado Veraniego          1
# Name: Barrio, Length: 149, dtype: int64

# %%
len(inmuebles.UPZ.value_counts())
# Out:
# 63

# %% [markdown]
# Para realizar graficos tenemos el siguiente ejemplo

# %%
inmuebles_barrio = inmuebles.Barrio.value_counts()
inmuebles_barrio.plot.bar()
# Out:
# <Axes: >

# %%
inmuebles_barrio.head(10).plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# # **Desafíos de esta aula**
# - Promedio del área de todos los inmuebles en los barrios en el dataset.
# - graficar el top 10
# - Consultar otros datos estadísticos como:
#   - conteo
#   - mediana
#   - valor mínimo
#   - valor máximo

# %%
# promedio de todos lo inmuebles en los barrios 
inmuebles.Area.mean()
# Out:
# 146.66470588235293

# %%
inmuebles.head(10).Area.plot.bar()
# Out:
# <Axes: >

# %%
inmuebles.Area.head(10).plot.bar()
# Out:
# <Axes: >

# %%
inmuebles.head(10).Area.mean()
# Out:
# 124.1

# %%
inmuebles.head(10).Area.value_counts()
# Out:
# 62     2
# 70     1
# 170    1
# 144    1
# 154    1
# 128    1
# 212    1
# 159    1
# 80     1
# Name: Area, dtype: int64

# %%
inmuebles.head(10).Area.count()
# Out:
# 10

# %%
inmuebles.head(10).Area.describe()
# Out:
# count     10.000000
# mean     124.100000
# std       52.642294
# min       62.000000
# 25%       72.500000
# 50%      136.000000
# 75%      157.750000
# max      212.000000
# Name: Area, dtype: float64

# %% [markdown]
# # **ALURA DAY 2**

# %%
inmuebles.sample(10)
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 4987  Apartamento         Apartamento en venta en Chico Norte             1
# 8814  Apartamento            Apartamento en venta en El Batán             3
# 8144  Apartamento      Apartamento en venta en Ciudad Bolívar             3
# 2739         Casa                   Casa en venta en Madelena             4
# 9115         Casa                  Casa en venta en Chapinero             3
# 888   Apartamento            Apartamento en venta en Engativa             3
# 6113  Apartamento       Apartamento en venta en Santa Barbara             2
# 8543  Apartamento        Apartamento en venta en Santa Teresa             3
# 4348  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 6069  Apartamento       Apartamento en venta en Santa Barbara             1
#
#       Banos  Area              Barrio  \
# 4987      1    76         Chico Norte
# 8814      2    75            El Batán
# 8144      2    56      Ciudad Bolívar
# 2739      2   210            Madelena
# 9115      3   341           Chapinero
# 888       2    67            Engativa
# 6113      3    81       Santa Barbara
# 8543      2    87        Santa Teresa
# 4348      1    43  Zona Noroccidental
# 6069      1    59       Santa Barbara
#
#                                                     UPZ            Valor
# 4987                 CHAPINERO: Chicó Lago + El Refugio    $ 834.460.000
# 8814                                        La Alhambra    $ 410.000.000
# 8144  CIUDAD BOLÍVAR: Monteblanco + El Tesoro + El M...    $ 230.000.000
# 2739                                       Arborizadora    $ 480.000.000
# 9115                 CHAPINERO: Pardo Rubio + Chapinero  $ 3.000.000.000
# 888                                            Engativá    $ 320.000.000
# 6113              USAQUÉN: Country Club + Santa Bárbara    $ 400.000.000
# 8543                                San Cristóbal Norte    $ 460.000.000
# 4348                 CHAPINERO: Pardo Rubio + Chapinero    $ 142.500.000
# 6069              USAQUÉN: Country Club + Santa Bárbara    $ 390.500.000

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 595.1+ KB

# %%
type(inmuebles.Valor[0]) #str

print(inmuebles.Valor[0] + inmuebles.Valor[1])
print(inmuebles.Valor[0])

print(inmuebles.Valor[0].split())

# separar toda la columna valor para obtener sus valores enteros que vendrian 
# a ser los precios 

#expand=True => nos devuelve un dataFrame, ya no un panda series
valor = inmuebles.Valor.str.split(expand=True)

inmuebles['Moneda'] = valor[0]
inmuebles['Precio'] = valor[1]
inmuebles.sample(3)
# Out:
# $ 360.000.000$ 670.000.000
# $ 360.000.000
# ['$', '360.000.000']
#              Tipo                      Descripcion  Habitaciones  Banos  Area  \
# 537   Apartamento  Apartamento en venta en Kennedy             1      1    32
# 1656         Casa  Casa en venta en Bosque Popular             3      2   148
# 3813         Casa         Casa en venta en Usaquén             5      4   154
#
#               Barrio              UPZ          Valor Moneda       Precio
# 537          Kennedy  Kennedy Central  $ 164.000.000      $  164.000.000
# 1656  Bosque Popular       Las Ferias  $ 630.000.000      $  630.000.000
# 3813         Usaquén          Usaquén  $ 630.000.000      $  630.000.000

# %%
# verificamos los types de nuestras nuevas columnas
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
#  8   Moneda        9520 non-null   object
#  9   Precio        9520 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 743.9+ KB

# %% [markdown]
# Verificamos que nuestra columna precio sigue siendo un string que contiene caracteres ".", ahora debemos eliminar estos caracteres

# %%
inmuebles['Precio'] = inmuebles.Precio.str.replace('.', '', regex=True)
inmuebles.sample(3)
# Out:
#              Tipo                       Descripcion  Habitaciones  Banos  \
# 9459         Casa          Casa en venta en Kennedy            10      3
# 3416  Apartamento  Apartamento en venta en Cedritos             3      2
# 3071         Casa    Casa en venta en Bosa Porvenir             2      2
#
#       Area         Barrio              UPZ          Valor Moneda     Precio
# 9459   139        Kennedy  Kennedy Central  $ 500.000.000      $  500000000
# 3416    75       Cedritos          Usaquén  $ 420.000.000      $  420000000
# 3071    42  Bosa Porvenir  Bosa Occidental  $ 133.000.000      $  133000000

# %%
inmuebles['Precio_millon'] = inmuebles.Precio.astype('float') / 1000000
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Tipo           9520 non-null   object
#  1   Descripcion    9520 non-null   object
#  2   Habitaciones   9520 non-null   int64
#  3   Banos          9520 non-null   int64
#  4   Area           9520 non-null   int64
#  5   Barrio         9520 non-null   object
#  6   UPZ            9478 non-null   object
#  7   Valor          9520 non-null   object
#  8   Moneda         9520 non-null   object
#  9   Precio         9520 non-null   object
#  10  Precio_millon  9520 non-null   float64
# dtypes: float64(1), int64(3), object(7)
# memory usage: 818.2+ KB

# %%
inmuebles[['Precio_millon', 'Barrio']]
# Out:
#       Precio_millon                  Barrio
# 0            360.00      Zona Noroccidental
# 1            670.00                Castilla
# 2           1120.00         Chico Reservado
# 3            890.00                 Usaquén
# 4            970.00             Bella Suiza
# ...             ...                     ...
# 9515         290.00                 Kennedy
# 9516         670.00  Parque Central Bavaria
# 9517         900.00                Restrepo
# 9518         335.00                Engativa
# 9519         144.99                 Tintala
#
# [9520 rows x 2 columns]

# %%
inmuebles.describe()
# Out:
#        Habitaciones        Banos           Area  Precio_millon
# count   9520.000000  9520.000000    9520.000000    9520.000000
# mean       3.072479     2.447899     146.664706     602.062354
# std        2.049856     1.255314    1731.379622     704.602062
# min        1.000000     0.000000       2.000000      60.000000
# 25%        2.000000     2.000000      57.000000     250.000000
# 50%        3.000000     2.000000      80.000000     409.182500
# 75%        3.000000     3.000000     135.000000     680.000000
# max      110.000000     9.000000  166243.000000   16000.000000

# %% [markdown]
# Ahora modificamos el formato en la cual tendra una mejor visualizacion, en otras palabras ajustamos las posiciones decimales.

# %%
# Funcion Lamda para ajustar los decimales
pd.set_option('display.precision', 2)
pd.set_option('display.float_format', lambda x: '%.2f' % x)
inmuebles.describe()
# Out:
#        Habitaciones   Banos      Area  Precio_millon
# count       9520.00 9520.00   9520.00        9520.00
# mean           3.07    2.45    146.66         602.06
# std            2.05    1.26   1731.38         704.60
# min            1.00    0.00      2.00          60.00
# 25%            2.00    2.00     57.00         250.00
# 50%            3.00    2.00     80.00         409.18
# 75%            3.00    3.00    135.00         680.00
# max          110.00    9.00 166243.00       16000.00

# %% [markdown]
# Con esta informacion podemos ir analizando cada columnda con su respectiva fila de resultados de operaciones.
#
# Encontramos un inmueble con 110 habitaciones, raro no? Bueno realizamos el tratamiento para veriicar de que trata. Y asi podemos ir encontrando datos atipicos los cuales necesitan ser revisados y analizados, este tratamiento de datos nos ayuda a que cuendo utilicemos ya en los modelos de entrenamiento no salgan afectadas igualmente.

# %%
inmuebles.loc[inmuebles.Habitaciones == 110]
# Out:
#      Tipo                Descripcion  Habitaciones  Banos  Area    Barrio  \
# 897  Casa  Casa en venta en La Uribe           110      2   110  La Uribe
#
#          UPZ          Valor Moneda     Precio  Precio_millon
# 897  Usaquén  $ 480.000.000      $  480000000         480.00

# %% [markdown]
# Como se puede observar tiene una igualdad con el area que tambien es 110, Una de las conclueciones es que puedo haber sido un error de typeo(escritura) de la informacion, porque es algo **Atipico**

# %% [markdown]
# # **Graficos**
#
# Veamos como podemos graficar nuestros datos para una mejor visualizacion de los mismos y poder sacar mas conluciones.

# %%
# los bins nos ayuda a establecer el rango que vamos a avarcar en nuestros histograma 
# a mas bins rango mas pequeno
# a menos bins el rango mas grande de barras
inmuebles['Precio_millon'].plot.hist(bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %%
inmuebles['Precio_millon'].plot.hist(bins=100)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# # **Bibliotecas para la Visualizacion de datos**
#
# - **[matplotlib](https://matplotlib.org/)**: Librearia que nos permite visualizar graficos para la visualizacion de nuestros datos
# - **[seaborn](https://seaborn.pydata.org/)**: Fue creada a partir de matplotlib con funciones visuales mas avanzadas y mas atractivas

# %%
import matplotlib.pyplot as plt
import seaborn as sns
 
# creamos nuestro lienzo
plt.figure(figsize=(10, 8))

#realizamos el grafico de nuestro histograma
grafica = sns.histplot(data=inmuebles, x='Precio_millon', kde=True, hue='Tipo')
grafica.set_title('Distribucion de valores de los inmuebles en Bogota')

# ponenmos el limite para una mejor visualizacion 
plt.xlim((50, 1000))
# plt.ylim((0, 20))
# gradar e importar en algun formato y donde lo queremos exportar
# plt.savefig('/content/drive/MyDrive/COURSES/imercion_de_datos_alura/valor_inmueble.png', format='png')
plt.show()

# %% [markdown]
# # **Desafio**
# 1:06:00
# 1.
#   - estudiar a mas profundidad el histograma
#   - seleccionar 3 tipos de inmuebles
#   - refinar el grafico: titulos, labels, fuentes, colores, etiquetas, etc.
#   - poner una concluecion de la informacino: como esta el precio de los apartamentos vs el precio de las fincas, etc.
# 2. Precio del m2 por barrio y hacer el grafico mas adecuado para esta nueva variable.
# (precio/m2)

# %% [markdown]
# # **Alura 3**
#
# clase 3 inmersion de datos

# %%
inmuebles['Valor_m2_Millon'] = inmuebles.Precio_millon / inmuebles.Area
inmuebles.head()
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Banos  Area              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor Moneda      Precio  Precio_millon  Valor_m2_Millon
# 0    $ 360.000.000      $   360000000         360.00             5.14
# 1    $ 670.000.000      $   670000000         670.00             3.94
# 2  $ 1.120.000.000      $  1120000000        1120.00             7.78
# 3    $ 890.000.000      $   890000000         890.00             5.78
# 4    $ 970.000.000      $   970000000         970.00             7.58

# %%
inmuebles.groupby('Barrio').mean()
# Out:
#                     Habitaciones  Banos   Area  Precio_millon  Valor_m2_Millon
# Barrio
# Alameda                     3.00   2.00  97.00         580.00             5.98
# Alhambra                    3.00   2.94 190.41         752.35             4.33
# Andes Norte                 3.00   2.86 124.86         709.57             6.05
# Antonio Nariño              4.31   2.50 163.06         459.22             3.53
# Barrancas                   2.87   2.13  70.20         314.13             4.42
# ...                          ...    ...    ...            ...              ...
# Villa Maria                 4.69   3.69 207.15         402.85             2.04
# Villas De Granada           3.45   2.32  86.59         282.30             3.17
# Villemar                    2.94   2.06  76.89         303.83             3.99
# Zona Franca                 2.00   1.00  54.00         160.00             2.96
# Zona Noroccidental          3.17   2.51 135.79         620.81             4.62
#
# [149 rows x 5 columns]

# %% [markdown]
# Otra forma de calcular el promedio para encontrar el precio por m2 de cada barrio es la siguiente:

# %%
datos_barrio = inmuebles.groupby('Barrio').sum()
datos_barrio
# Out:
#                     Habitaciones  Banos    Area  Precio_millon  \
# Barrio
# Alameda                        3      2      97         580.00
# Alhambra                      51     50    3237       12790.00
# Andes Norte                   21     20     874        4967.00
# Antonio Nariño               207    120    7827       22042.65
# Barrancas                     43     32    1053        4712.00
# ...                          ...    ...     ...            ...
# Villa Maria                   61     48    2693        5237.00
# Villas De Granada             76     51    1905        6210.62
# Villemar                      53     37    1384        5469.00
# Zona Franca                    2      1      54         160.00
# Zona Noroccidental          2778   2204  119084      544453.06
#
#                     Valor_m2_Millon
# Barrio
# Alameda                        5.98
# Alhambra                      73.56
# Andes Norte                   42.35
# Antonio Nariño               169.47
# Barrancas                     66.24
# ...                             ...
# Villa Maria                   26.58
# Villas De Granada             69.71
# Villemar                      71.81
# Zona Franca                    2.96
# Zona Noroccidental          4049.16
#
# [149 rows x 5 columns]

# %%
datos_barrio['Valor_m2_Barrio'] = datos_barrio['Precio_millon'] / datos_barrio['Area']
datos_barrio
# Out:
#                     Habitaciones  Banos    Area  Precio_millon  \
# Barrio
# Alameda                        3      2      97         580.00
# Alhambra                      51     50    3237       12790.00
# Andes Norte                   21     20     874        4967.00
# Antonio Nariño               207    120    7827       22042.65
# Barrancas                     43     32    1053        4712.00
# ...                          ...    ...     ...            ...
# Villa Maria                   61     48    2693        5237.00
# Villas De Granada             76     51    1905        6210.62
# Villemar                      53     37    1384        5469.00
# Zona Franca                    2      1      54         160.00
# Zona Noroccidental          2778   2204  119084      544453.06
#
#                     Valor_m2_Millon  Valor_m2_Barrio
# Barrio
# Alameda                        5.98             5.98
# Alhambra                      73.56             3.95
# Andes Norte                   42.35             5.68
# Antonio Nariño               169.47             2.82
# Barrancas                     66.24             4.47
# ...                             ...              ...
# Villa Maria                   26.58             1.94
# Villas De Granada             69.71             3.26
# Villemar                      71.81             3.95
# Zona Franca                    2.96             2.96
# Zona Noroccidental          4049.16             4.57
#
# [149 rows x 6 columns]

# %% [markdown]
# ## **Trabajamos con diccionarios**

# %%
inmuebles.head()
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Banos  Area              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor Moneda      Precio  Precio_millon  Valor_m2_Millon
# 0    $ 360.000.000      $   360000000         360.00             5.14
# 1    $ 670.000.000      $   670000000         670.00             3.94
# 2  $ 1.120.000.000      $  1120000000        1120.00             7.78
# 3    $ 890.000.000      $   890000000         890.00             5.78
# 4    $ 970.000.000      $   970000000         970.00             7.58

# %%
datos_barrio.head()
# Out:
#                 Habitaciones  Banos  Area  Precio_millon  Valor_m2_Millon  \
# Barrio
# Alameda                    3      2    97         580.00             5.98
# Alhambra                  51     50  3237       12790.00            73.56
# Andes Norte               21     20   874        4967.00            42.35
# Antonio Nariño           207    120  7827       22042.65           169.47
# Barrancas                 43     32  1053        4712.00            66.24
#
#                 Valor_m2_Barrio
# Barrio
# Alameda                    5.98
# Alhambra                   3.95
# Andes Norte                5.68
# Antonio Nariño             2.82
# Barrancas                  4.47

# %% [markdown]
# Necesitamos obtener la columna Valor_m2_Barrio y asignar a nuestro frame de inmuebles para ello realizamos lo siguiente generando el diccionario.

# %%
m2_barrio = dict(datos_barrio['Valor_m2_Barrio'])

# %%
inmuebles['Valor_m2_Barrio'] = inmuebles['Barrio']
inmuebles['Valor_m2_Barrio'] = inmuebles['Valor_m2_Barrio'].map(m2_barrio)
inmuebles.head()
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Banos  Area              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor Moneda      Precio  Precio_millon  Valor_m2_Millon  \
# 0    $ 360.000.000      $   360000000         360.00             5.14
# 1    $ 670.000.000      $   670000000         670.00             3.94
# 2  $ 1.120.000.000      $  1120000000        1120.00             7.78
# 3    $ 890.000.000      $   890000000         890.00             5.78
# 4    $ 970.000.000      $   970000000         970.00             7.58
#
#    Valor_m2_Barrio
# 0             4.57
# 1             3.40
# 2             8.10
# 3             5.66
# 4             6.29

# %% [markdown]
# loa 10 Barrios que tienen mas inmuebles a la venta

# %%
inmuebles['Barrio'].value_counts()[:10].index
# Out:
# Index(['Usaquén', 'Zona Noroccidental', 'Bosa', 'Kennedy', 'Cedritos',
#        'Barrios Unidos', 'Engativa', 'Suba', 'Santa Barbara', 'Chapinero'],
#       dtype='object')

# %%
#asignamos los top 10 barrios a nuestra nueva variable data set
top_barrios = inmuebles['Barrio'].value_counts()[:10].index

# %%
print(datos_barrio)
#reasignamos los indices ya que ahora se muestra  a los Barrios commo indices
# inplace = nos permite reasignar a la misma variable
datos_barrio.reset_index(inplace=True)
# Out:
#                  Barrio  Habitaciones  Banos    Area  Precio_millon  \
# 0               Alameda             3      2      97         580.00
# 1              Alhambra            51     50    3237       12790.00
# 2           Andes Norte            21     20     874        4967.00
# 3        Antonio Nariño           207    120    7827       22042.65
# 4             Barrancas            43     32    1053        4712.00
# ..                  ...           ...    ...     ...            ...
# 144         Villa Maria            61     48    2693        5237.00
# 145   Villas De Granada            76     51    1905        6210.62
# 146            Villemar            53     37    1384        5469.00
# 147         Zona Franca             2      1      54         160.00
# 148  Zona Noroccidental          2778   2204  119084      544453.06
#
#      Valor_m2_Millon  Valor_m2_Barrio
# 0               5.98             5.98
# 1              73.56             3.95
# 2              42.35             5.68
# 3             169.47             2.82
# 4              66.24             4.47
# ..               ...              ...
# 144            26.58             1.94
# 145            69.71             3.26
# 146            71.81             3.95
# 147             2.96             2.96
# 148          4049.16             4.57
#
# [149 rows x 7 columns]

# %%
datos_barrio
# Out:
#                  Barrio  Habitaciones  Banos    Area  Precio_millon  \
# 0               Alameda             3      2      97         580.00
# 1              Alhambra            51     50    3237       12790.00
# 2           Andes Norte            21     20     874        4967.00
# 3        Antonio Nariño           207    120    7827       22042.65
# 4             Barrancas            43     32    1053        4712.00
# ..                  ...           ...    ...     ...            ...
# 144         Villa Maria            61     48    2693        5237.00
# 145   Villas De Granada            76     51    1905        6210.62
# 146            Villemar            53     37    1384        5469.00
# 147         Zona Franca             2      1      54         160.00
# 148  Zona Noroccidental          2778   2204  119084      544453.06
#
#      Valor_m2_Millon  Valor_m2_Barrio
# 0               5.98             5.98
# 1              73.56             3.95
# 2              42.35             5.68
# 3             169.47             2.82
# 4              66.24             4.47
# ..               ...              ...
# 144            26.58             1.94
# 145            69.71             3.26
# 146            71.81             3.95
# 147             2.96             2.96
# 148          4049.16             4.57
#
# [149 rows x 7 columns]

# %% [markdown]
# ### **Manejo de Queries**
#
# @ : hace referencia al data set

# %%
#despues de obtener los top 10 barrios hacemos referencia en nuestro data set 
# de barrios que esten en nuestro top 10 
datos_barrio.query('Barrio in @top_barrios')
# Out:
#                  Barrio  Habitaciones  Banos    Area  Precio_millon  \
# 5        Barrios Unidos          1525   1196   87799      259877.76
# 10                 Bosa          1743    789   34879       93400.56
# 22             Cedritos          1458   1348   53711      270027.73
# 24            Chapinero           892    913   81248      372130.93
# 50             Engativa          1676   1077   59808      172711.73
# 63              Kennedy          2151   1233   61475      207963.65
# 125       Santa Barbara          1073   1162   54693      320097.80
# 132                Suba          1497   1202   61615      266406.04
# 138             Usaquén          3109   3044  148121      837710.36
# 148  Zona Noroccidental          2778   2204  119084      544453.06
#
#      Valor_m2_Millon  Valor_m2_Barrio
# 5            2070.61             2.96
# 10           1654.36             2.68
# 22           2853.23             5.03
# 24           2466.03             4.58
# 50           1795.71             2.89
# 63           2127.66             3.38
# 125          2701.88             5.85
# 132          2000.72             4.32
# 138          6334.04             5.66
# 148          4049.16             4.57

# %% [markdown]
# ## **Graficamos**

# %%
#generamos e lienzo
plt.figure(figsize=(10,8))
ax = sns.barplot(data=datos_barrio.query('Barrio in @top_barrios'), x='Barrio' , y='Valor_m2_Barrio')
#ajustamos los parametros de nuestro puntos tick
ax.tick_params(axis='x', rotation=45)

# %%
#generamos e lienzo
plt.figure(figsize=(10,8))
ax = sns.boxplot(data=inmuebles.query('Barrio in @top_barrios'), x='Barrio' , y='Valor_m2_Millon')
#ajustamos los parametros de nuestro puntos tick
ax.tick_params(axis='x', rotation=45)
plt.show()

# %%
#generamos e lienzo
plt.figure(figsize=(10,8))

# Eliminamos los outlayes agregando condicion al Query
ax = sns.boxplot(data=inmuebles.query('Barrio in @top_barrios & Valor_m2_Millon < 15'), x='Barrio' , y='Valor_m2_Millon')
#ajustamos los parametros de nuestro puntos tick
ax.tick_params(axis='x', rotation=45)
plt.show()

# %%
#generamos e lienzo
plt.figure(figsize=(10,8))

# cambiamos nuestros ejes referenciales ahora con Area y 
# ponemos la condicion para tener una mejor apreciacion
ax = sns.boxplot(data=inmuebles.query('Barrio in @top_barrios & Area < 500'), x='Barrio' , y='Area')
#ajustamos los parametros de nuestro puntos tick
ax.tick_params(axis='x', rotation=45)
plt.show()

# %% [markdown]
# Cuando nuestros datos estan muy dispersos pueden perjudicar el desempeno de nuestro modelo, debemos saber identificar.
# conclusion: vemos que en chapineros existen inmuebles con superficies mas amplias por ensima de la media 50%

# %%
#generamos e lienzo
plt.figure(figsize=(10,8))

# cambiamos nuestros ejes con Precio_millon y la condicion
ax = sns.boxplot(data=inmuebles.query('Barrio in @top_barrios & Precio_millon < 3000'), x='Barrio' , y='Precio_millon')
#ajustamos los parametros de nuestro puntos tick
ax.tick_params(axis='x', rotation=45)
plt.show()

# %% [markdown]
# Vamos a traer datos estadísticos de la ciudad de Bogotá, directamente del DANE y vamos a ver como estos datos nos ayudarían en inclusión de nuevas variables para el cálculo del precio de los inmuebles en la ciudad de Bogotá.
#
# Encuesta Multiproposito de Bogotá para obtener información socio-económica y de entorno urbano de los habitantes de Bogotá para la formulación, seguimiento y evaluación de las políticas distritales.
#
# https://microdatos.dane.gov.co/index.php/catalog/743

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

datos_raw = pd.read_csv('/content/drive/MyDrive/COURSES/imercion_de_datos_alura/Identificación (Capítulo A).csv', sep = ';',encoding='latin-1')
datos_raw.head()
# Out:
#    DIRECTORIO  DPTO   MPIO  CLASE  COD_LOCALIDAD NOMBRE_LOCALIDAD  \
# 0   3004346.0    11  11001      1            3.0         Santa Fe
# 1   3004347.0    11  11001      1           14.0     Los Mártires
# 2   3004348.0    11  11001      1            3.0         Santa Fe
# 3   3004349.0    11  11001      1            1.0          Usaquén
# 4   3004350.0    11  11001      1            1.0          Usaquén
#
#    COD_UPZ_GRUPO                        NOMBRE_UPZ_GRUPO  ESTRATO2021  \
# 0          814.0  SANTA FE: Las Nieves + Sagrado Corazón     11001187
# 1           37.0                            Santa Isabel     11001162
# 2          814.0  SANTA FE: Las Nieves + Sagrado Corazón     11001187
# 3          803.0   USAQUÉN: Country Club + Santa Bárbara     11001176
# 4          803.0   USAQUÉN: Country Club + Santa Bárbara     11001176
#
#                            NOMBRE_ESTRATO             FEX_C
# 0  SANTA FE: Las Nieves + Sagrado Corazón  13,2266692027239
# 1                            Santa Isabel  17,8555889419101
# 2  SANTA FE: Las Nieves + Sagrado Corazón  10,0286103658331
# 3   USAQUÉN: Country Club + Santa Bárbara  28,6502122142802
# 4   USAQUÉN: Country Club + Santa Bárbara  24,4684068319009

# %%
datos_raw.shape
# Out:
# (106467, 11)

# %% [markdown]
# ahora solo recolectamos los datos de MPIO de 11001 y descartamos las otras

# %%
datos_raw = datos_raw.loc[datos_raw.MPIO == 11001]
datos_raw.shape
# Out:
# (86504, 11)

# %% [markdown]
# ### **Importamos nuestros sets de datos del DANAE**

# %%
datos_b = pd.read_csv('/content/drive/MyDrive/COURSES/imercion_de_datos_alura/Datos de la vivenda y su entorno (Capítulo B).csv', sep = ';',encoding='latin-1')
datos_c = pd.read_csv('/content/drive/MyDrive/COURSES/imercion_de_datos_alura/Condiciones habitacionales del hogar (Capítulo C).csv', sep = ';',encoding='latin-1')
datos_e = pd.read_csv('/content/drive/MyDrive/COURSES/imercion_de_datos_alura/Composición del hogar y demografía (Capítulo E).csv', sep = ';',encoding='latin-1')
datos_h = pd.read_csv('/content/drive/MyDrive/COURSES/imercion_de_datos_alura/Educación (Capítulo H).csv', sep = ';',encoding='latin-1')
datos_k = pd.read_csv('/content/drive/MyDrive/COURSES/imercion_de_datos_alura/Fuerza de trabajo (Capítulo K).csv', sep = ';',encoding='latin-1')
datos_l = pd.read_csv('/content/drive/MyDrive/COURSES/imercion_de_datos_alura/Percepción sobre las condiciones de vida y el desempeño institucional (Capítulo L).csv', sep = ';',encoding='latin-1')
# Out:
# <ipython-input-9-213f344af9e1>:2: DtypeWarning: Columns (4,25,30,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_c = pd.read_csv('/content/drive/MyDrive/COURSES/imercion_de_datos_alura/Condiciones habitacionales del hogar (Capítulo C).csv', sep = ';',encoding='latin-1')
# <ipython-input-9-213f344af9e1>:3: DtypeWarning: Columns (66) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_e = pd.read_csv('/content/drive/MyDrive/COURSES/imercion_de_datos_alura/Composición del hogar y demografía (Capítulo E).csv', sep = ';',encoding='latin-1')
# <ipython-input-9-213f344af9e1>:4: DtypeWarning: Columns (81) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_h = pd.read_csv('/content/drive/MyDrive/COURSES/imercion_de_datos_alura/Educación (Capítulo H).csv', sep = ';',encoding='latin-1')
# <ipython-input-9-213f344af9e1>:5: DtypeWarning: Columns (27,58,60,62,64,66,104,114,120,124,126,129,131,133) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_k = pd.read_csv('/content/drive/MyDrive/COURSES/imercion_de_datos_alura/Fuerza de trabajo (Capítulo K).csv', sep = ';',encoding='latin-1')
# <ipython-input-9-213f344af9e1>:6: DtypeWarning: Columns (114,117,122,126,164,166,168) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_l = pd.read_csv('/content/drive/MyDrive/COURSES/imercion_de_datos_alura/Percepción sobre las condiciones de vida y el desempeño institucional (Capítulo L).csv', sep = ';',encoding='latin-1')

# %% [markdown]
# Realizamos la union de nuestras tablas en un solo frame utilizando la funcion de pandas Merge

# %%
# on: campo con el cual se relacionan ambas tablas
# how=left : es una especificacion de leftjoin en sql union a la izquierda
datos_dane = pd.merge(datos_raw, datos_b, on='DIRECTORIO', how='left')
datos_dane.sample(2)
# Out:
# (86504, 73)

# %%
datos_dane.sample(2)
# Out:
#        DIRECTORIO  DPTO   MPIO  CLASE  COD_LOCALIDAD NOMBRE_LOCALIDAD  \
# 11379    338641.0    11  11001      1            2.0        Chapinero
# 47336   1060254.0    11  11001      1           11.0             Suba
#
#        COD_UPZ_GRUPO                    NOMBRE_UPZ_GRUPO  ESTRATO2021  \
# 11379          817.0  CHAPINERO: Chicó Lago + El Refugio     11001190
# 47336           28.0                           El Rincón     11001122
#
#                            NOMBRE_ESTRATO  ... NVCBP15J  NVCBP15K  NVCBP15L  \
# 11379  CHAPINERO: Chicó Lago + El Refugio  ...        2         2         2
# 47336                           El Rincón  ...        2         2         2
#
#        NVCBP15M  NVCBP16A1  NVCBP16A2  NVCBP16A3  NVCBP16A4  NVCBP16  \
# 11379         2          2          2          2          2        1
# 47336         2          2          2          2          2        2
#
#                 FEX_C_y
# 11379  23,0046226728147
# 47336  137,572623497482
#
# [2 rows x 73 columns]

# %%
datos_dane = pd.merge(datos_dane, datos_c, on='DIRECTORIO', how='left')
datos_dane.shape
# Out:
# (87061, 214)

# %%
datos_dane = pd.merge(datos_dane, datos_e, on='DIRECTORIO', how='left')
datos_dane.shape
# Out:
# <ipython-input-13-31131df05887>:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'FEX_C_x'} in the result is deprecated and will raise a MergeError in a future version.
#   datos_dane = pd.merge(datos_dane, datos_e, on='DIRECTORIO', how='left')
# (238559, 281)

# %%
datos_dane.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 238559 entries, 0 to 238558
# Columns: 281 entries, DIRECTORIO to FEX_C_y
# dtypes: float64(140), int64(126), object(15)
# memory usage: 513.3+ MB

# %% [markdown]
# # **Reto nuemero 3 dia 3**
#
# 1. Dar un vistazo a la base de datos de DANE, entender estas variables conceptualmente para entender mejor el contexto de la base de datos.
# 2. Organizar el Notbook para que el proyecto quede mejor presentado.
